# %%
import re
import json
import sys
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
! pip install bs4

# %%
def scrape():
    url = "https://www.textonlyrecipes.com"
    try:
        response = requests.get(url)
        print(response)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            links = soup.find_all('a', href=lambda href: href and 
                                  href.startswith('/recipes/'))
            
            # Extract and store only the GSM values
            link_values = [link["href"] for link in links]

            for recipelink in link_values:
                recipe_url = "https://www.textonlyrecipes.com" + recipelink
                recipeResponse = requests.get(recipe_url)
                recipeSoup = BeautifulSoup(response.text, 'html.parser')
           

            #return link_values
    
        return "Failed to retrieve the page. Status code: {0}".format(response.status_code)
    
    except requests.exceptions.RequestException as e:
        return "Error: {0}".format(e)

# %%
scrape()
# Out:
# <Response [200]>
# https://www.textonlyrecipes.com/recipes/almond-meal-chicken-fingers
# https://www.textonlyrecipes.com/recipes/amish-breakfast-casserole
# https://www.textonlyrecipes.com/recipes/apple-pie
# https://www.textonlyrecipes.com/recipes/baked-salmon
# https://www.textonlyrecipes.com/recipes/baked-ziti
# https://www.textonlyrecipes.com/recipes/baklava
# https://www.textonlyrecipes.com/recipes/banana-bread
# https://www.textonlyrecipes.com/recipes/banana-nut-muffins
# https://www.textonlyrecipes.com/recipes/barbecue-sauce
# https://www.textonlyrecipes.com/recipes/beef-stew
# https://www.textonlyrecipes.com/recipes/beef-stir-fry
# https://www.textonlyrecipes.com/recipes/beef-wellington
# https://www.textonlyrecipes.com/recipes/blueberry-crumble-bars
# https://www.textonlyrecipes.com/recipes/blueberry-muffins
# https://www.textonlyrecipes.com/recipes/blueberry-topping
# https://www.textonlyrecipes.com/recipes/caesar-salad
# ...
